# %% [markdown]
# **SQL SERVER**

# %% [markdown]
# 1.Nube privada:Acceder data center

# %% [markdown]
# 2.Nube publica : Servicio Cloud(LINODE,AZURE,AWS...OTRAS)

# %% [markdown]
# Almacenamiento de Base de datos

# %% [markdown]
# Credenciales proporcionados por el Dba

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\sergi\anaconda3\lib\site-packages (2.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc

# %%
import pyodbc
import psycopg2
import pandas as pd
import pandas.io.sql

# %%
conexion = pyodbc.connect('DRIVER={SQL Server};SERVER=69.164.192.245;DATABASE=alumno;UID=sdc_read;PWD=#sDc_Read#21')
# Parámetros
#SERVER = '69.164.192.245'
#DATABASE = 'alumno'
#UID = 'sdc_read'
#PWD = '#sDc_Read#21'

# %% [markdown]
# **Creamos un cursor de ejecución** (permite ejecutar Codigo)

# %%
cursor = conexion.cursor()

# %% [markdown]
# **Ejecutar consultas a la tabla** SELECT * FROM STUDENT.CLIENTES

# %%
cursor.execute("SELECT * FROM STUDENT.CLIENTES")

# %%
fila=cursor.fetchall()

# %%
fila
# Out:
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Representante de ventas', 'Obere Str. 57', 'Berlín', None, '12209', 'Alemania', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Propietario', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'México', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Propietario', 'Mataderos  2312', 'México D.F.', None, '05023', 'México', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Representante de ventas', '120 Hanover Sq.', 'Londres', None, 'WA1 1DP', 'Reino Unido', '(71) 555-7788', '(71) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Administrador de pedidos', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Suecia', '0921-12 34 65', '0921-12 34 67'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Representante de ventas', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Alemania', '0621-08460', '0621-08924'),
#  ('BLONP', 'Blondel père et fils', 'Frédérique Citeaux', 'Gerente de marketing', '24, place Kléber', 'Estrasburgo', None, '67000', 'Francia', '88.60.15.31', '88.60.15.32'),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 'Propietario', 'C/ Araquil, 67', 'Madrid', None, '28023', 'España', '(91) 555 22 82', '(91) 555 91 99'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Propietario', '12, rue des Bouchers', 'Marsella', None, '13008', 'Francia', '91.24.45.40', '91.24.45.41'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Gerente de contabilidad', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canadá', '(604) 555-4729', '(604) 555-3745'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Representante de ventas', 'Fauntleroy Circus', 'Londres', None, 'EC2 5NT', 'Reino Unido', '(71) 555-1212', None),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Agente de ventas', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Gerente de marketing', 'Sierras de Granada 9993', 'México D.F.', None, '05022', 'México', '(5) 555-3392', '(5) 555-7293'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Propietario', 'Hauptstr. 29', 'Berna', None, '3012', 'Suiza', '0452-076545', None),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 'Asistente de ventas', 'Av. dos Lusíadas, 23', 'São Paulo', 'SP', '05432-043', 'Brasil', '(11) 555-7647', None),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Representante de ventas', 'Berkeley Gardens12  Brewery ', 'Londres', None, 'WX1 6LT', 'Reino Unido', '(71) 555-2282', '(71) 555-9199'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Administrador de pedidos', 'Walserweg 21', 'Aachen', None, '52066', 'Alemania', '0241-039123', '0241-059428'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Propietario', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'Francia', '40.67.88.88', '40.67.89.89'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Agente de ventas', '35 King George', 'Londres', None, 'WX3 6FW', 'Reino Unido', '(71) 555-0297', '(71) 555-3373'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Gerente de ventas', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Asistente de marketing', 'Rua Orós, 92', 'Sao Paulo', 'SP', '05442-030', 'Brasil', '(11) 555-9857', None),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Gerente de contabilidad', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'España', '(91) 555 94 44', '(91) 555 55 93'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 'Asistente de agente de ventas', '184, chaussée de Tournai', 'Lille', None, '59000', 'Francia', '20.16.10.16', '20.16.10.17'),
#  ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 'Propietario', 'Åkergatan 24', 'Bräcke', None, 'S-844 67', 'Suecia', '0695-34 67 21', None),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Gerente de marketing', 'Berliner Platz 43', 'München', None, '80805', 'Alemania', '089-0877310', '089-0877451'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Gerente de marketing', '54, rue Royale', 'Nantes', None, '44000', 'Francia', '40.32.21.21', '40.32.21.20'),
#  ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Representante de ventas', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italia', '011-4988260', '011-4988261'),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez ', 'Gerente de ventas', 'Jardim das rosas n. 32', 'Lisboa', None, '1675', 'Portugal', '(1) 354-2534', '(1) 354-2535'),
#  ('GALED', 'Galería del gastrónomo', 'Eduardo Saavedra', 'Gerente de marketing', 'Rambla de Cataluña, 23', 'Barcelona', None, '08022', 'España', '(93) 203 4560', '(93) 203 4561'),
#  ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 'Gerente de ventas', 'C/ Romero, 33', 'Sevilla', None, '41101', 'España', '(95) 555 82 82', None),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 'Asistente de ventas', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brasil', '(11) 555-9482', None),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Gerente de marketing', '2732 Baker Blvd.', 'Eugenia', 'OR', '97403', 'Estados Unidos', '(503) 555-7555', None),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Propietario', '5ª Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Gerente de contabilidad', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brasil', '(21) 555-0091', '(21) 555-8765'),
#  ('HILAA', 'HILARIÓN-Abastos', 'Carlos Hernández', 'Representante de ventas', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', 'Táchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Representante de ventas', 'City Center Plaza516 Main St.', 'Elgin', 'OR', '97827', 'Estados Unidos', '(503) 555-6874', '(503) 555-2376'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Asistente de ventas', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Irlanda', '2967 542', '2967 3333'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Gerente de marketing', 'Garden HouseCrowther Way', 'Cowes', 'Isla de Wight', 'PO31 7PJ', 'Reino Unido', '(198) 555-8888', None),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 'Asistente de ventas', 'Maubelstr. 90', 'Brandenburgo', None, '14776', 'Alemania', '0555-09876', None),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Representante de ventas', "67, avenue de l'Europe", 'Versalles', None, '78000', 'Francia', '30.59.84.10', '30.59.85.11'),
#  ('LAMAI', "La maison d'Asie", 'Annette Roulet', 'Gerente de ventas', '1 rue Alsace-Lorraine', 'Toulouse', None, '31000', 'Francia', '61.77.61.10', '61.77.61.11'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Asistente de marketing', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canadá', '(604) 555-3392', '(604) 555-7293'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Gerente de marketing', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'Estados Unidos', '(509) 555-7969', '(509) 555-6221'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Representante de ventas', 'Magazinweg 7', 'Francfurt', None, '60528', 'Alemania', '069-0245984', '069-0245874'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Propietario', '87 Polk St.Suite 5', 'San Francisco', 'CA', '94117', 'Estados Unidos', '(415) 555-5938', None),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 'Gerente de contabilidad', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Propietario', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Gerente de ventas', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'Estados Unidos', '(503) 555-9573', '(503) 555-9646'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Gerente de marketing', 'Via Ludovico il Moro 22', 'Bérgamo', None, '24100', 'Italia', '035-640230', '035-640231'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Agente de ventas', 'Rue Joseph-Bens 532', 'Bruselas', None, 'B-1180', 'Bélgica', '(02) 201 24 67', '(02) 201 24 68'),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 'Asistente de marketing', '43 rue St. Laurent', 'Montreal', 'Québec', 'H1J 1C3', 'Canadá', '(514) 555-8054', '(514) 555-8055'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Asistente de marketing', 'Heerstr. 22', 'Leipzig', None, '04179', 'Alemania', '0342-023176', None),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Asistente de ventas', 'South House300 Queensbridge', 'Londres', None, 'SW7 1RZ', 'Reino Unido', '(71) 555-7733', '(71) 555-2530'),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Agente de ventas', 'Ing. Gustavo Moncada 8585Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Representante de ventas', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'Estados Unidos', '(907) 555-7584', '(907) 555-2880'),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Propietario', 'Mehrheimerstr. 369', 'Köln', None, '50739', 'Alemania', '0221-0644327', '0221-0765721'),
#  ('PARIS', 'Paris spécialités', 'Marie Bertrand', 'Propietario', '265, boulevard Charonne', 'París', None, '75012', 'Francia', '(1) 42.34.22.66', '(1) 42.34.22.77'),
#  ('PERIC', 'Pericles Comidas clásicas', 'Guillermo Fernández', 'Representante de ventas', 'Calle Dr. Jorge Cash 321', 'México D.F.', None, '05033', 'México', '(5) 552-3745', '(5) 545-3745'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Gerente de ventas', 'Geislweg 14', 'Salzburgo', None, '5020', 'Austria', '6562-9722', '6562-9723'),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Representante de ventas', 'Estrada da saúde n. 58', 'Lisboa', None, '1756', 'Portugal', '(1) 356-5634', None),
#  ('QUEDE', 'Que Delícia', 'Bernardo Batista', 'Gerente de contabilidad', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brasil', '(21) 555-4252', '(21) 555-4545'),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 'Asistente de marketing', 'Alameda dos Canàrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brasil', '(11) 555-1189', None),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Gerente de contabilidad', 'Taucherstraße 10', 'Cunewalde', None, '01307', 'Alemania', '0372-035188', None),
#  ('RANCH', 'Rancho grande', 'Sergio Gutiérrez', 'Representante de ventas', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Representante agente ventas', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'Estados Unidos', '(505) 555-5939', '(505) 555-3620'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Asistente de ventas', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italia', '0522-556721', '0522-556722'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Asistente de agente de ventas', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brasil', '(21) 555-3412', None),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Gerente de ventas', 'Grenzacherweg 237', 'Génova', None, '1203', 'Suiza', '0897-034214', None),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Gerente de contabilidad', 'Gran Vía, 1', 'Madrid', None, '28001', 'España', '(91) 745 6200', '(91) 745 6210'),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 'Propietario', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Noruega', '07-98 92 35', '07-98 92 47'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Representante de ventas', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'Estados Unidos', '(208) 555-8097', None),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Gerente de ventas', '90 Wadhurst Rd.', 'Londres', None, 'OX15 4NB', 'Reino Unido', '(71) 555-1717', '(71) 555-5646'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Propietario', 'Vinbæltet 34', 'København', None, '1734', 'Dinamarca', '31 12 34 56', '31 13 35 57'),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 'Gerente de marketing', '25, rue Lauriston', 'París', None, '75016', 'Francia', '(1) 47.55.60.10', '(1) 47.55.60.20'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Gerente de ventas', 'P.O. Box 555', 'Lander', 'WY', '82520', 'Estados Unidos', '(307) 555-4680', '(307) 555-6525'),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 'Gerente de contabilidad', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Bélgica', '(071) 23 67 22 20', '(071) 23 67 22 21'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Gerente de marketing', '89 Jefferson WaySuite 2', 'Portland', 'OR', '97201', 'Estados Unidos', '(503) 555-3612', None),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Asistente de marketing', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'Estados Unidos', '(406) 555-5834', '(406) 555-8083'),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 'Gerente de marketing', 'Luisenstr. 48', 'Münster', None, '44087', 'Alemania', '0251-031259', '0251-035695'),
#  ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Propietario', 'Avda. Azteca 123', 'México D.F.', None, '05033', 'México', '(5) 555-2933', None),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 'Representante de ventas', 'Av. Inês de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brasil', '(11) 555-2167', '(11) 555-2168'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Asistente de ventas', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'Estados Unidos', '(206) 555-8257', '(206) 555-2174'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Gerente de ventas', 'Smagsløget 45', 'Århus', None, '8200', 'Dinamarca', '86 21 32 43', '86 22 33 44'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Agente de ventas', '2, rue du Commerce', 'Lion', None, '69004', 'Francia', '78.32.54.86', '78.32.54.87'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Gerente de contabilidad', "59 rue de l'Abbaye", 'Reims', None, '51100', 'Francia', '26.47.15.10', '26.47.15.11'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 'Representante de ventas', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Alemania', '0711-020361', '0711-035428'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Gerente de contabilidad', 'Torikatu 38', 'Oulu', None, '90110', 'Finlandia', '981-443655', '981-443655'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Gerente de ventas', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brasil', '(14) 555-8122', None),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Propietario', '305 - 14th Ave. S.Suite 3B', 'Seattle', 'WA', '98128', 'Estados Unidos', '(206) 555-4112', '(206) 555-4115'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Prop./Asistente marketing', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finlandia', '90-224 8858', '90-224 8858'),
#  ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'Propietario', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Polonia', '(26) 642-7012', '(26) 642-7012')]

# %% [markdown]
# **Convertimos la matriz de datos en un DataFrame**

# %%
import numpy as np

# %%
df_sql= pd.DataFrame(np.array(fila))

# %%
df_sql.head()
# Out:
#       0                                   1                   2   \
# 0  ALFKI                 Alfreds Futterkiste        Maria Anders
# 1  ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2  ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3  AROUT                     Around the Horn        Thomas Hardy
# 4  BERGS                  Berglunds snabbköp  Christina Berglund
#
#                          3                              4            5     6   \
# 0   Representante de ventas                  Obere Str. 57       Berlín  None
# 1               Propietario  Avda. de la Constitución 2222  México D.F.  None
# 2               Propietario                Mataderos  2312  México D.F.  None
# 3   Representante de ventas                120 Hanover Sq.      Londres  None
# 4  Administrador de pedidos                Berguvsvägen  8        Luleå  None
#
#          7            8              9              10
# 0     12209     Alemania    030-0074321    030-0076545
# 1     05021       México   (5) 555-4729   (5) 555-3745
# 2     05023       México   (5) 555-3932           None
# 3   WA1 1DP  Reino Unido  (71) 555-7788  (71) 555-6750
# 4  S-958 22       Suecia  0921-12 34 65  0921-12 34 67

# %%
df_sql.columns=["Codigo","Apellidos","Nombres","Cargo","Direccion","Estado","NA","Codigo2","Pais","Telefono","Telefono2"]

# %%
df_sql.head()
# Out:
#   Codigo                           Apellidos             Nombres  \
# 0  ALFKI                 Alfreds Futterkiste        Maria Anders
# 1  ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2  ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3  AROUT                     Around the Horn        Thomas Hardy
# 4  BERGS                  Berglunds snabbköp  Christina Berglund
#
#                       Cargo                      Direccion       Estado    NA  \
# 0   Representante de ventas                  Obere Str. 57       Berlín  None
# 1               Propietario  Avda. de la Constitución 2222  México D.F.  None
# 2               Propietario                Mataderos  2312  México D.F.  None
# 3   Representante de ventas                120 Hanover Sq.      Londres  None
# 4  Administrador de pedidos                Berguvsvägen  8        Luleå  None
#
#     Codigo2         Pais       Telefono      Telefono2
# 0     12209     Alemania    030-0074321    030-0076545
# 1     05021       México   (5) 555-4729   (5) 555-3745
# 2     05023       México   (5) 555-3932           None
# 3   WA1 1DP  Reino Unido  (71) 555-7788  (71) 555-6750
# 4  S-958 22       Suecia  0921-12 34 65  0921-12 34 67

# %% [markdown]
# **CERRAR LA CONEXION A LA BASE DE DATOS SQL SERVER**

# %%
conexion.close()

# %% [markdown]
# **CONEXION AL POSTGRESQL**

# %%
import psycopg2
import pandas as pd

# %%
conPostg = psycopg2.connect("dbname=alumno user=postgres password=sdc2019PERU host=69.164.192.245")

# %%
cursor= conPostg.cursor()

# %%
cursor.execute("select * from books")

# %%
filas=cursor.fetchall()

# %%
filas
# Out:
# [('Big Data', 'Dawn E. Holmes', 'S/ 117,98', 'S/ 82,58'),
#  ('Big Data Para Directivos', 'Genis Roca', 'S/ 113,05', 'S/ 79,14'),
#  ('Big Data: La Utilización del big Data, el Análisis y los Parámetros Smart Para Tomar Mejores Decisiones y Aumentar el Rendimiento',
#   'Bernard Marr',
#   'S/ 166,14',
#   'S/ 116,30'),
#  ('Data Strategy: Como Beneficiarse de un Mundo de big Data, Analytics e Internet',
#   'Bernard Marr',
#   'S/ 118,42',
#   'S/ 82,89'),
#  ('Big Data, el Poder de los Datos',
#   'Bill Schmarzo',
#   'S/ 186,11',
#   'S/ 130,27'),
#  ('Big Data y el Internet de las Cosas: Qué hay Detrás y Cómo nos va a Cambiar',
#   'Mario Tascon',
#   'S/ 120,93',
#   'S/ 84,65'),
#  ('Aprender con big Data',
#   'Viktor Mayer-Schönberger; Kenneth Cukier',
#   'S/ 95,40',
#   'S/ 66,78'),
#  ('Big Data en Recursos Humanos', 'Bernard Marr', 'S/ 130,09', 'S/ 91,07'),
#  ('Big Data: Atrapando al Consumidor',
#   'Josep Francesc Valls',
#   'S/ 119,68',
#   'S/ 83,77'),
#  ('Big Data', 'David Ríos Insua', 'S/ 108,93', 'S/ 76,25'),
#  ('Big Data', 'Luis Joyanes Aguilar', 'S/ 192,10', 'S/ 134,47'),
#  ('Las Bases de big Data',
#   'Rafael Caballero Roldán,Enrique Martín Martín',
#   'S/ 120,93',
#   'S/ 84,65'),
#  ('Big Data & Politica de los Relatos a los Datos Persuadir en la era de las Redes Sociales',
#   'Luciano Galup',
#   'S/ 88,86',
#   'S/ 62,20'),
#  ('Big Data: La Revolución de los Datos Masivos',
#   'Viktor Mayer Schönberger,Kenneth Cukier',
#   'S/ 135,68',
#   'S/ 94,98'),
#  ('Big Data. Joyanes. 1Ed', '', 'S/ 148,97', 'S/ 104,28'),
#  ('Big Data en Rr. Hh.', 'Bernard Marr', 'S/ 166,14', 'S/ 116,30'),
#  ('Big Data. Tecnicas Herramientas y Aplicaciones',
#   'Maria Perez Marques',
#   'S/ 157,58',
#   'S/ 110,30'),
#  ('Una Ética Para big Data. Introducción a la Gestión Ética de Datos Masivos (Manuales)',
#   'Colmenarejo',
#   '',
#   'S/ 75,01'),
#  ('Data Management Platform (Dmp) big Data',
#   'Oscar Lopezcuesta',
#   'S/ 121,35',
#   'S/ 84,95'),
#  ('Data Science: A Comprehensive Guide to Data Science, Data Analytics, Data Mining, Artificial Intelligence, Machine Learning, and big Data (libro en Inglés)',
#   'Richard Hurley',
#   'S/ 195,24',
#   'S/ 136,67'),
#  ('Analítica Predictiva. Predecir el Futuro Utilizando big Data (Títulos Especiales)',
#   'Eric Siegel',
#   'S/ 275,81',
#   'S/ 193,07'),
#  ('Big Data for Dummies', 'Hurwitz, Judith', 'S/ 228,90', 'S/ 160,23'),
#  ('Big Data. Ifct128Po', 'José Antonio Castillo Romero', '', 'S/ 121,69'),
#  ('Big Data. Técnicas, Herramientas y Aplicaciones',
#   'María Pérez Marqués',
#   'S/ 205,35',
#   'S/ 143,75'),
#  ('La Nube: Big Data es un Mundo Turbulento',
#   'Vincent Mosco',
#   'S/ 188,90',
#   'S/ 132,23'),
#  ('Television del Futuro Streaming big Data on Demand y el Nuevo Espectador (',
#   'Notar N.',
#   'S/ 85,56',
#   'S/ 59,89'),
#  ('Big Data. Desafíos También Para el Derecho (Papel + E',
#   'Wolfgang Hoffmann-Riem',
#   'S/ 138,57',
#   'S/ 97,00'),
#  ('Con que Sueñan los Algoritmos: Nuestras Vidas en el Tiempo de los big Data',
#   'Dominique Cardon',
#   'S/ 145,10',
#   'S/ 101,57'),
#  ('Hadoop: Soluciones big Data',
#   'Boris Lublinsky,Kevin T. Smith,Alexey Yakubovich',
#   'S/ 315,56',
#   'S/ 220,89'),
#  ('Big Data a Escala Humana', 'Colin Strong', 'S/ 150,47', 'S/ 105,33'),
#  ('Big Data MBA: Driving Business Strategies with Data Science',
#   'Bill Schmarzo',
#   'S/ 286,29',
#   'S/ 200,41'),
#  ('Big Data Analisis de Datos en Entornos Masivos',
#   'Varios Autores',
#   'S/ 220,39',
#   'S/ 154,28'),
#  ('Big Data: Using Smart Big Data, Analytics and Metrics to Make Better Decisions and Improve Performance',
#   'Bernard B Marr',
#   'S/ 165,11',
#   'S/ 115,58'),
#  ('Data Scientist y Lenguaje r Guía de Autoformación Para el uso de big Data',
#   'Henri Laude',
#   'S/ 338,75',
#   'S/ 237,12'),
#  ('Big Data en Educación. El Futuro Digital del Aprendizaje, la Política y la Práctica',
#   'Ben Williamson',
#   'S/ 180,91',
#   'S/ 126,64'),
#  ('DATA STRATEGY: CÓMO BENEFICIARSE DE UN MUNDO DE BIG DATA, ANALYTICS E INTERNET DE LAS COSAS',
#   'Bernard Marr',
#   'S/ 166,14',
#   'S/ 116,30'),
#  ('Big Data con Python. Recolección, Almacenamiento y Proceso',
#   'Rafael Caballero, Enrique Martín,Adrián Riesco',
#   'S/ 123,61',
#   'S/ 86,52'),
#  ('Big Data. Anal. De Grandes Vol. De Datos',
#   'Joyanes',
#   'S/ 165,13',
#   'S/ 115,59'),
#  ('La Izquierda que Asaltó al Algoritmo: Fraternidad y Digna Rabia en Tiempos del big Data (Mayor)',
#   'Juan Carlos Monedero',
#   'S/ 142,06',
#   'S/ 99,44'),
#  ('Resolviendo Problemas de big Data',
#   'Varios Autores',
#   'S/ 113,77',
#   'S/ 79,64'),
#  ('Big Data. Gestión y Explotación de Grandes Volúmenes de Datos (el Profesional de la Información)',
#   'Montserrat García-Alsina',
#   'S/ 133,46',
#   'S/ 93,42'),
#  ('Data Strategy. Como Beneficiarse de un Mundo de big Data Analytics e Internet de las Cosas',
#   'Varios',
#   'S/ 155,72',
#   'S/ 109,00'),
#  ('Big Data Analytics: Turning Big Data Into Big Money',
#   'Ohlhorst, Frank J.',
#   'S/ 318,80',
#   'S/ 223,16'),
#  ('Big Data For Beginners: Understanding SMART Big Data, Data Mining & Data Analytics For improved Business Performance, Life Decisions & More! (Data ... Computer Programming, Growth Hacking, ITIL)',
#   'Vince Reynolds',
#   'S/ 118,36',
#   'S/ 82,85'),
#  ('Big Data, Big Dupe: A little book about a big bunch of nonsense',
#   'Stephen Few',
#   'S/ 115,74',
#   'S/ 81,02'),
#  ('Modelado en big data', 'Aldana Montes', 'S/ 172,14', 'S/ 120,50'),
#  ('Big Data: A Primer (Studies in Big Data)', '', 'S/ 462,25', 'S/ 323,58'),
#  ('The Big Data', 'Russell Glass', 'S/ 236,24', 'S/ 165,37'),
#  ('Big Data. Surviving the Information Revolution (Hot Science) (libro en Inglés)',
#   'Brian Clegg',
#   'S/ 77,42',
#   'S/ 54,19'),
#  ('Information Granularity, big Data, and Computational Intelligence (Studies in big Data) (libro en Inglés)',
#   'Witold Pedrycz,shyi-ming Chen',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Big Data, una Oportunidad de Mejora en las Organizaciones',
#   'Daniel Trejo Medina',
#   'S/ 198,28',
#   'S/ 138,80'),
#  ('Big Data: Análisis de Datos con Python',
#   'Yolanda García Ruíz; Antonio Sarasa Cabezuelo',
#   'S/ 243,22',
#   'S/ 170,26'),
#  ('Big Data Glossary (libro en Inglés)',
#   'Pete Warden',
#   'S/ 187,96',
#   'S/ 131,57'),
#  ('Working with Big Data and Machine Learning',
#   'Mr V V Srinivas',
#   'S/ 124,58',
#   'S/ 87,21'),
#  ('La Reinvención de la Economía: El Capitalismo en la era del big Data (Noema)',
#   'Viktor Mayer-Sch&Ouml;Nberger; Thomas Ramge',
#   'S/ 168,56',
#   'S/ 117,99'),
#  ('Big Data: A Guide to big Data Trends, Artificial Intelligence, Machine Learning, Predictive Analytics, Internet of Things, Data Science, Data Analytics, Business Intelligence, and Data Mining (libro en Inglés)',
#   'Richard Hurley',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Big Data: Understanding How Data Powers Big Business',
#   'Bill Schmarzo',
#   'S/ 285,97',
#   'S/ 200,18'),
#  ('Big Data for the Greater Good (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Big Data Demystified: How Big Data Is Changing The Way We Live, Love And Learn',
#   'David Feinleib',
#   'S/ 136,78',
#   'S/ 95,75'),
#  ('Big Data Como Activo de Negocio',
#   'Sánchez Rojo, Eduardo,Muñoz Vera, Gemma',
#   'S/ 156,83',
#   'S/ 109,78'),
#  ('Ingeniería del big Data, la. Cómo Trabajar con Datos (Manuales)',
#   'Juan José López Murphy',
#   'S/ 157,10',
#   'S/ 109,97'),
#  ('Big Data for Dummies', 'Hurwitz, Judith', 'S/ 228,88', 'S/ 160,22'),
#  ('Data Science and big Data: An Environment of Computational Intelligence (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('El Derecho Al Olvido En Internet: Del Caso Google Al Big Data (spanish Edition)',
#   'Juan Antonio Gallo Sallent',
#   'S/ 210,56',
#   'S/ 147,39'),
#  ('Guide to Big Data Applications (Studies in Big Data)',
#   '',
#   'S/ 1.678,16',
#   'S/ 1.174,71'),
#  ('Disruptive Possibilities: How big Data Changes Everything (libro en Inglés)',
#   'Jeffrey Needham',
#   'S/ 220,71',
#   'S/ 154,50'),
#  ('Data Strategy: How to Profit from a World of Big Data, Analytics and the Internet of Things',
#   'Bernard Marr',
#   'S/ 204,17',
#   'S/ 142,92'),
#  ('Big Data: Principles and Best Practices of Scalable Realtime Data Systems (libro en inglés)',
#   'Nathan Marz; James Warren',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Big Data Management', '', 'S/ 1.309,70', 'S/ 916,79'),
#  ('Big Data Shocks (libro en Inglés)', '', 'S/ 793,95', 'S/ 555,76'),
#  ('Big Data Analytics', 'Venkat Ankam', 'S/ 466,35', 'S/ 326,44'),
#  ('Statistics For Big Data For Dummies',
#   'Alan Anderson',
#   'S/ 207,32',
#   'S/ 145,13'),
#  ('Data Science and Big Data Analytics', '', 'S/ 390,49', 'S/ 273,35'),
#  ('Everybody Lies: Big Data, new Data, and What the Internet can Tell us About who we Really are (libro en Inglés)',
#   'Seth Stephens-Davidowitz',
#   'S/ 175,76',
#   'S/ 123,03'),
#  ('Big Data con Python: Recoleccion, Almacenamiento',
#   'Beiroa',
#   'S/ 138,13',
#   'S/ 96,69'),
#  ('Manual sobre utilidades del big data para bienes públicos',
#   'Varios Autores',
#   'S/ 139,10',
#   'S/ 97,37'),
#  ('The Data Revolution: Big Data, Open Data, Data Infrastructures And Their Consequences',
#   'Rob Kitchin',
#   'S/ 373,91',
#   'S/ 261,73'),
#  ('Sharing big Data Safely (libro en Inglés)',
#   'Ted Dunning',
#   'S/ 220,71',
#   'S/ 154,50'),
#  ('Weapons of Math Destruction: How big Data Increases Inequality and Threatens Democracy (libro en Inglés)',
#   "Cathy O'neil",
#   'S/ 110,25',
#   'S/ 77,18'),
#  ('Uncharted: Big Data as a Lens on Human Culture (libro en Inglés)',
#   'Erez Aiden; Jean-Baptiste Michel',
#   'S/ 122,54',
#   'S/ 85,78'),
#  ('Big Data Revolution: What Farmers, Doctors and Insurance Agents Teach us About Discovering big Data Patterns (libro en inglés)',
#   'Rob Thomas; Patrick Mcsharry',
#   'S/ 171,58',
#   'S/ 120,11'),
#  ('Humanizing big Data: Marketing at the Meeting of Data, Social Science and Consumer Insight (libro en Inglés)',
#   'Colin Strong',
#   'S/ 253,30',
#   'S/ 177,31'),
#  ('Data Science and Big Data: An Environment of Computational Intelligence (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Big Data Cloud Computing y Otros Retos Jurídicos Planteados por las Tecnologías Emergentes (Dúo)',
#   'Apol&Middot;L&Ograve;Nia Mart&Iacute;Nez Nadal',
#   'S/ 195,15',
#   'S/ 136,60'),
#  ('Big Data Overview', 'Dabhade Karan', 'S/ 280,11', 'S/ 196,08'),
#  ('Big Data Demystified: How to Use Big Data, Data Science and AI to Make Better Business Decisions and Gain Competitive Advantage',
#   'David Stephenson',
#   'S/ 183,05',
#   'S/ 128,13'),
#  ('Machine Intelligence and Big Data in Industry (Studies in Big Data)',
#   '',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Big Data Optimization: Recent Developments and Challenges (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Cultura Visual y Conocimiento Científico: Comunicación Transmedia de la Ciencia en la era big Data',
#   'Francisco José López Cantos',
#   'S/ 126,93',
#   'S/ 88,85'),
#  ('Big data y periodismo en la sociedad red',
#   'Carlos Elías Pérez',
#   'S/ 157,10',
#   'S/ 109,97'),
#  ('Big Data: A Very Short Introduction (Very Short Introductions) (libro en Inglés)',
#   'Dawn E Holmes',
#   'S/ 115,74',
#   'S/ 81,02'),
#  ('Big Data Visualization', 'James D. Miller', 'S/ 425,41', 'S/ 297,79'),
#  ('Big Data and Democracy (libro en Inglés)', '', 'S/ 912,67', 'S/ 638,87'),
#  ('I Like big Data and Coffee: Dot Grid Page Notebook Gift for Computer Data Science Related People. (libro en Inglés)',
#   'Teesson Inc',
#   'S/ 99,94',
#   'S/ 69,96'),
#  ('Compromised Data: From Social Media To Big Data',
#   'Axel Bruns',
#   'S/ 343,20',
#   'S/ 240,24'),
#  ('BIG DATA. TECNICAS, HERRAMIENTAS Y APLIC',
#   'Pérez',
#   'S/ 148,26',
#   'S/ 103,78'),
#  ('The Politics and Policies of big Data: Big Data, big Brother? (Routledge Research in Information Technology and Society) (libro en inglés)',
#   '',
#   'S/ 1.326,16',
#   'S/ 928,31'),
#  ('High Performance Data Mining and Big Data Analytics',
#   'Hassibi, Khosrow',
#   'S/ 371,45',
#   'S/ 260,01'),
#  ('INTRODUCCION AL BIG DATA (En papel)', '', 'S/ 365,87', 'S/ 256,11'),
#  ('Data Science: What the Best Data Scientists Know About Data Analytics, Data Mining, Statistics, Machine Learning, and big Data',
#   'Herbert Jones',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ("Data Analytics: An Essential Beginner's Guide to Data Mining, Data Collection, big Data Analytics for Business, and Business Intelligence Concepts (libro en Inglés)",
#   'Herbert Jones',
#   'S/ 185,03',
#   'S/ 129,52'),
#  ('Big Data, Little Data, No Data: Scholarship in the Networked World',
#   'Christine L. Borgman',
#   'S/ 253,54',
#   'S/ 177,48'),
#  ('Big Data Recommender Systems: Algorithms, Architectures, big Data, Security and Trust (Computing and Networks) (libro en Inglés)',
#   '',
#   'S/ 945,42',
#   'S/ 661,80'),
#  ('Big Data, big Analytics (Wiley Cio) (libro en Inglés)',
#   'Michael Minelli',
#   'S/ 328,00',
#   'S/ 229,60'),
#  ('An Introduction to Data: Everything you Need to Know About ai, big Data and Data Science (Studies in big Data) (libro en inglés)',
#   'Francesco Corea',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Text Mining: Concepts, Implementation, and big Data Challenge (Studies in big Data) (libro en Inglés)',
#   'Taeho Jo',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Scalable big Data Architecture: A Practitioners Guide to Choosing Relevant big Data Architecture (libro en Inglés)',
#   'Bahaaldine Azarmi',
#   'S/ 351,72',
#   'S/ 246,20'),
#  ('Big Data Analytics: Una Perspectiva Multidisciplinaria Para la Mejora del Proceso de Toma de Decisiones en las Organizaciones',
#   'Jose Alberto Hernandezaguilar',
#   'S/ 132,47',
#   'S/ 92,73'),
#  ('Big Data At Work: Dispelling The Myths, Uncovering The Opportunities',
#   'Thomas H. Davenport',
#   'S/ 228,98',
#   'S/ 160,29'),
#  ('Big Data Analysis: New Algorithms For A New Society (studies In Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Big Data in Complex Systems: Challenges and Opportunities (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Harness the Power of big Data the ibm big Data Platform (libro en Inglés)',
#   'Paul Zikopoulos; Dirk Deroos; Krishnan Parasuraman; Thomas Deutsch; James Giles; David Corrigan',
#   'S/ 155,29',
#   'S/ 108,70'),
#  ('Intelligent Methods and Big Data in Industrial Applications (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Big Data Analysis: New Algorithms For A New Society (studies In Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Big Data Analysis', 'Otsuki Akira', 'S/ 304,28', 'S/ 213,00'),
#  ('El Trabajo Social Ante el Reto de la Transformación Digital (Papel + E',
#   'Joaquín Castillo De Mesa',
#   'S/ 217,44',
#   'S/ 152,21'),
#  ('VISUALIZACION Y CONSUMO DE BIG DATA',
#   'JOSÉ FRANCISCO ALDANA MONTES,JOSE GARCIA NIETO',
#   'S/ 241,43',
#   'S/ 169,00'),
#  ('Big Data en Recursos Humanos: Analitycs y Metricas Para Optimizar el Rendimiento',
#   'Bernard Marr',
#   'S/ 171,99',
#   'S/ 120,39'),
#  ('Big Data for Insurance Companies (Innovation, Entrepreneurship and Management: Big Data, Artificial Intelligence and Data Analysis)',
#   '',
#   'S/ 805,09',
#   'S/ 563,56'),
#  ('Data Privacy: Foundations, New Developments and the Big Data Challenge (Studies in Big Data)',
#   'Vicenç Torra',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Ethics of Big Data',
#   'Davis, Kord/ Patterson, Doug',
#   'S/ 187,96',
#   'S/ 131,57'),
#  ('Data Mining and Knowledge Discovery for Big Data: Methodologies, Challenge and Opportunities (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Taming the Big Data Tidal Wave: Finding Opportunities in Huge Data Streams with Advanced Analytics',
#   'Franks, Bill',
#   'S/ 338,66',
#   'S/ 237,06'),
#  ("The Efficiency Paradox: What big Data Can't do (libro en Inglés)",
#   'Edward Tenner',
#   'S/ 126,47',
#   'S/ 88,53'),
#  ('Data Science: The Ultimate Guide to Data Analytics, Data Mining, Data Warehousing, Data Visualization, Regression Analysis, Database Querying, big Data for Business and Machine Learning for Beginners (libro en Inglés)',
#   'Herbert Jones',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Data Analytics: The Ultimate Guide to big Data Analytics for Business, Data Mining Techniques, Data Collection, and Business Intelligence Concepts (libro en Inglés)',
#   'Herbert Jones',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Data Mining for Service (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('From Big Data to Smart Data', 'Fernando Iafrate', 'S/ 386,91', 'S/ 270,84'),
#  ('Data Lake Development with Big Data',
#   'Pradeep Pasupuleti',
#   'S/ 343,53',
#   'S/ 240,47'),
#  ('Big Data: Die Gesellschaft als digitale Maschine',
#   '',
#   'S/ 241,16',
#   'S/ 168,81'),
#  ('Encyclopedia of big Data Technologies (libro en Inglés)',
#   '',
#   'S/ 6.689,16',
#   'S/ 4.682,41'),
#  ('I Like big Data and i Cannot Lie: Dot Grid Page Notebook Gift for Computer Data Science Related People. (libro en Inglés)',
#   'Teesson Inc',
#   'S/ 99,94',
#   'S/ 69,96'),
#  ('Big Data for Small Business For Dummies',
#   'Bernard Marr',
#   'S/ 169,94',
#   'S/ 118,96'),
#  ('Aprendizaje Automático: El Aprendizaje Automático Para Principiantes que Desean Comprender Aplicaciones, Inteligencia Artificial, Minería de Datos, big Data y más',
#   'Herbert Jones',
#   'S/ 185,30',
#   'S/ 129,71'),
#  ('Big Data and Visual Analytics (libro en Inglés)',
#   '',
#   'S/ 1.236,01',
#   'S/ 865,21'),
#  ('The Big Data Opportunity in Our Driverless Future',
#   'Evangelos Simoudis',
#   'S/ 130,48',
#   'S/ 91,34'),
#  ('Big Data Analytics With R', 'Simon Walkowiak', 'S/ 507,29', 'S/ 355,10'),
#  ('Handbook of big Data Privacy (libro en Inglés)',
#   '',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Inside the Impact of big Data (Inside Impact) (libro en inglés)',
#   'Jim Fleigner',
#   'S/ 136,70',
#   'S/ 95,69'),
#  ('Big Data: Conceptual Analysis and Applications (Studies in big Data) (libro en Inglés)',
#   'Michael Z. Zgurovsky; Yuriy P. Zaychenko',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Handbook of Big Data Technologies', '', 'S/ 2.857,22', 'S/ 2.000,05'),
#  ('Understanding Azure Data Factory: Operationalizing big Data and Advanced Analytics Solutions (libro en Inglés)',
#   'Sudhir Rawat',
#   'S/ 243,64',
#   'S/ 170,55'),
#  ('Reinventing Capitalism in the age of big Data (libro en inglés)',
#   'Varios Autores',
#   'S/ 149,13',
#   'S/ 104,39'),
#  ('Internet Of Things And Big Data Analytics Toward Next',
#   'Nilanjan Dey,aboul Ella Hassanien,chintan Bhatt,amira S. Ashour,suresh Chandra Satapathy',
#   'S/ 2.120,31',
#   'S/ 1.484,21'),
#  ('Granular Computing Based Machine Learning: A Big Data Processing Approach (Studies in Big Data)',
#   'Han Liu',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ("Déchiffrer le Big Data, Simplement.: Acquérir les outils pour agir, de la réflexion à l'usage.",
#   'Pierre J. L. Brunelle',
#   'S/ 93,80',
#   'S/ 65,66'),
#  ('Big Data Exclusions and Disparate Impact: Investigating the exclusionary dynamics of the Big Data phenomenon',
#   'Charly Gordon',
#   'S/ 280,11',
#   'S/ 196,08'),
#  ('Wandel von Data Warehouse Architekturen im Zeitalter von Big Data',
#   '',
#   'S/ 225,50',
#   'S/ 157,85'),
#  ('Big Data, Objets Connectés et Predictive Data (French Edition)',
#   'Sacha Mourain',
#   'S/ 280,11',
#   'S/ 196,08'),
#  ('Successful Business Intelligence: Unlock The Value Of Bi & Big Data, Second Edition',
#   'Cindi Howson',
#   'S/ 263,37',
#   'S/ 184,36'),
#  ('Big Data Shocks: An Introduction to big Data for Librarians and Information Professionals (Lita Guides) (libro en Inglés)',
#   'Andrew Weiss',
#   'S/ 425,49',
#   'S/ 297,84'),
#  ('Smart Cities: Big Data, Civic Hackers, And The Quest For A New Utopia',
#   'Anthony M. Townsend',
#   'S/ 145,22',
#   'S/ 101,65'),
#  ('Analítica de Datos: La Guía Definitiva de Análisis de big Data Para Empresas, Técnicas de Minería de Datos, Recopilación de Datos y Conceptos de Inteligencia Empresarial',
#   'Herbert Jones',
#   'S/ 194,43',
#   'S/ 136,10'),
#  ('Big Data for Managers (libro en Inglés)',
#   'Atal Malviya',
#   'S/ 515,15',
#   'S/ 360,60'),
#  ('Cloud Computing for Geospatial big Data Analytics: Intelligent Edge, fog and Mist Computing (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Big Data: Conceptos, Tecnologías y Aplicaciones: 108 (¿ Qué Sabemos De? )',
#   'David R&Iacute;Os Insua; David G&Oacute;Mez-Ullate Oteiza',
#   'S/ 114,04',
#   'S/ 79,83'),
#  ('Big Data, Cloud Computing, Data Science & Engineering (Studies in Computational Intelligence) (libro en Inglés)',
#   '',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Astronomy and Big Data: A Data Clustering Approach to Identifying Uncertain Galaxy Morphology (Studies in Big Data)',
#   'Kieran Jay Edwards',
#   'S/ 1.236,01',
#   'S/ 865,21'),
#  ('Big Data Analytics: Methods and Applications (libro en Inglés)',
#   '',
#   'S/ 793,86',
#   'S/ 555,70'),
#  ('Big Data Analytics (Database Management Systems) (libro en Inglés)',
#   '',
#   'S/ 945,42',
#   'S/ 661,80'),
#  ('Big Data In Practice: How 45 Successful Companies Used Big Data Analytics To Deliver Extraordinary Results',
#   'Wiley',
#   'S/ 285,66',
#   'S/ 199,96'),
#  ('Big Data, Big Value ?: Antagonisme ou complémentarité ? (French Edition)',
#   'Najoie Hami-Eddine',
#   'S/ 261,31',
#   'S/ 182,92'),
#  ('Talend for big Data (libro en Inglés)',
#   'Bahaaldine Azarmi',
#   'S/ 363,81',
#   'S/ 254,67'),
#  ('Big Data, Health Law, and Bioethics (libro en Inglés)',
#   '',
#   'S/ 613,73',
#   'S/ 429,61'),
#  ('Advances in Mobile Cloud Computing and Big Data in the 5G Era (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Big Data: Does Size Matter? (Bloomsbury Sigma)',
#   'Timandra Harkness',
#   'S/ 211,78',
#   'S/ 148,25'),
#  ('Simulación de Redes Neuronales Como Herramienta big Data en el Ámbito Sanitario',
#   'Marcos Redondo Fonseca',
#   'S/ 278,94',
#   'S/ 195,26'),
#  ('Strategic Data', 'John Girard', 'S/ 1.399,85', 'S/ 979,90'),
#  ('Practical Big Data Analytics',
#   'Nataraj Dasgupta',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Using R to Unlock the Value of Big Data: Big Data Analytics with Oracle R Enterprise and Oracle R Connector for Hadoop',
#   'Mark Hornick',
#   'S/ 179,85',
#   'S/ 125,90'),
#  ('BIG DATA EN EDUCACION. EL FUTURO DIGITAL DEL APRENDIZAJE, LA',
#   'BEN WILLIAMSON',
#   'S/ 256,83',
#   'S/ 179,78'),
#  ('Data Versus Democracy: How big Data Algorithms Shape Opinions and Alter the Course of History (libro en Inglés)',
#   'Kris Shaffer',
#   'S/ 194,51',
#   'S/ 136,16'),
#  ('Too big to Ignore: The Business Case for big Data (Wiley and sas Business Series) (libro en inglés)',
#   'Phil Simon',
#   'S/ 186,55',
#   'S/ 130,59'),
#  ('The Big Data Agenda: Data Ethics and Critical Data Studies (Critical Digital and Social Media Studies Series)',
#   'Annika Richterich',
#   'S/ 223,35',
#   'S/ 156,34'),
#  ('Advances in Data Science: Symbolic, Complex, and Network Data (Innovation, Entrepreneurship, Management; Big Data, Intelligence and Data Analaysis) (libro en Inglés)',
#   'Diday',
#   'S/ 828,55',
#   'S/ 579,98'),
#  ('Metaheuristics for Big Data (Computer Engineering Series: Metaheuristics Set)',
#   'Clarisse Dhaenens',
#   'S/ 644,21',
#   'S/ 450,95'),
#  ('Highlighting the Importance of Big Data Management and Analysis for Various Applications (Studies in Big Data)',
#   '',
#   'S/ 867,56',
#   'S/ 607,29'),
#  ('Big Data Processing', 'Dr. M. Mohemmed Sha Dr.', 'S/ 671,13', 'S/ 469,79'),
#  ('Big Data Analytics Using Splunk: Deriving Operational Intelligence From Social Media, Machine Data, Existing Data Warehouses, and Other Real',
#   'Peter Zadrozny',
#   'S/ 388,56',
#   'S/ 271,99'),
#  ('Next generation computing and big data analytics',
#   'United States Congress',
#   'S/ 198,19',
#   'S/ 138,74'),
#  ('Big data and agriculture : innovation and implications',
#   'United States Congress',
#   'S/ 198,19',
#   'S/ 138,74'),
#  ('Data Science Landscape: Towards Research Standards and Protocols (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('The Enterprise big Data Lake (libro en Inglés)',
#   'Alex Gorelik',
#   'S/ 400,84',
#   'S/ 280,59'),
#  ('The Big Book of Dashboards: Visualizing Your Data Using Real',
#   'Steve Wexler',
#   'S/ 275,76',
#   'S/ 193,03'),
#  ('Big Data Computing: A Guide for Business and Technology Managers (Chapman & Hall/CRC Big Data Series)',
#   'Vivek Kale',
#   'S/ 1.571,80',
#   'S/ 1.100,26'),
#  ('Numbersense: How to use big Data to Your Advantage (libro en Inglés)',
#   'Kaiser Fung',
#   'S/ 194,10',
#   'S/ 135,87'),
#  ('Big Data Approach for Anomaly Detection',
#   'Namrata Verma',
#   'S/ 280,11',
#   'S/ 196,08'),
#  ('Predictive Analytics: The Secret to Predicting Future Events Using big Data and Data Science Techniques Such as Data Mining, Predictive Modelling, Statistics, Data Analysis, and Machine Learning (libro en Inglés)',
#   'Richard Hurley',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Big Data Integration (Synthesis Lectures on Data Management)',
#   'Xin Luna Dong',
#   'S/ 536,03',
#   'S/ 375,22'),
#  ('Privacy, big Data, and the Public Good (libro en Inglés)',
#   '',
#   'S/ 752,92',
#   'S/ 527,05'),
#  ('Big Data, Health Law, and Bioethics (libro en Inglés)',
#   'Cohen',
#   'S/ 1.228,19',
#   'S/ 859,73'),
#  ('Scaling Big Data With Hadoop And Solr',
#   'Hrishikesh Karambelkar',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Big Data and Business Analytics (libro en inglés)',
#   'Liebowitz. Jay',
#   'S/ 703,47',
#   'S/ 492,43'),
#  ('Big Data Privacy: A Complete Guide (libro en inglés)',
#   'Gerardus Blokdyk',
#   'S/ 542,17',
#   'S/ 379,52'),
#  ('Big Data, Open Data and Data Development',
#   'Jean-Louis Monino',
#   'S/ 563,46',
#   'S/ 394,42'),
#  ('Next', 'Butch Quinto', 'S/ 253,46', 'S/ 177,42'),
#  ('Big Data: A Revolution That Will Transform How We Live, Work, And Think',
#   'Viktor Mayer-schönberger,kenneth Cukier',
#   'S/ 135,39',
#   'S/ 94,77'),
#  ('Data Science and big Data Analytics: Acm',
#   'Wir 2018 (Lecture Notes On Data Engineering And Communications Technologies) (libro En Inglés)',
#   'S/ 1.678,16',
#   'S/ 1.174,71'),
#  ("Big Data Imperatives: Enterprise 'big Data' Warehouse, 'bi' Implementations and Analytics (The Expert's Voice) (libro en Inglés)",
#   'Soumendra Mohanty; Madhu Jagadeesh; Harsha Srivatsa',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Weapons of Math Destruction: How Big Data Increases Inequality and Threatens Democracy',
#   "CATHY O'NEIL",
#   'S/ 118,42',
#   'S/ 82,90'),
#  ('Big Data Technologies and Applications',
#   'Borko Furht',
#   'S/ 1.236,01',
#   'S/ 865,21'),
#  ('Conquering Big Data with High Performance Computing',
#   '',
#   'S/ 1.530,78',
#   'S/ 1.071,54'),
#  ('Analítica De Datos: Una Guía Esencial Para Principiantes En Minería De Datos, Recolección De Datos, Análisis De Big Data Para Negocios Y Conceptos De Inteligencia Empresarial (spanish Edition)',
#   'Herbert Jones',
#   'S/ 138,91',
#   'S/ 97,24'),
#  ('Big Data and Official Statistics',
#   'Carlo Vaccari',
#   'S/ 400,07',
#   'S/ 280,05'),
#  ('Big Data Analysen (libro en Alemán)',
#   'Sebastian Muller',
#   'S/ 413,13',
#   'S/ 289,19'),
#  ('Reinventing Capitalism in the Age of Big Data',
#   'Viktor Mayer-Schnberger',
#   'S/ 191,56',
#   'S/ 134,09'),
#  ('Thinking big Data in Geography: New Regimes, new Research (libro en inglés)',
#   '',
#   'S/ 278,11',
#   'S/ 194,67'),
#  ('Big data and agriculture : innovation in the air',
#   'United States Congress',
#   'S/ 198,19',
#   'S/ 138,74'),
#  ('Integration von Big Data Technologien in ein Enterprise Data Warehouse',
#   'Loer Philipp',
#   'S/ 400,07',
#   'S/ 280,05'),
#  ('Beginning big Data With Power bi and Excel 2013: Big Data Processing and Analysis Using Powerbi in Excel 2013 (libro en Inglés)',
#   'Neil Dunlop',
#   'S/ 351,72',
#   'S/ 246,20'),
#  ('Data Strategy and the Enterprise Data Executive: Ensuring that Business and IT are in Synch in the Post',
#   'Peter Aiken',
#   'S/ 210,10',
#   'S/ 147,07'),
#  ('Big Data Forensics – Learning Hadoop Investigations (libro en Inglés)',
#   'Joe Sremack',
#   'S/ 466,59',
#   'S/ 326,61'),
#  ("Big Data: A Beginner's Introduction (libro en Inglés)",
#   'Saswat Sarangi; Pankaj Sharma',
#   'S/ 425,08',
#   'S/ 297,56'),
#  ('Big Data in Predictive Toxicology (Issues in Toxicology) (libro en Inglés)',
#   '',
#   'S/ 1.796,97',
#   'S/ 1.257,88'),
#  ('Big Data A Tool for Inclusion or Exclusion? Understanding the Issues',
#   'Federal Trade Commission',
#   'S/ 136,54',
#   'S/ 95,58'),
#  ('Madison Miles and the Big, Big Move',
#   'Dara Nichole',
#   'S/ 155,29',
#   'S/ 108,70'),
#  ('Systems Analytics and Integration of big Omics Data (libro en Inglés)',
#   '',
#   'S/ 431,14',
#   'S/ 301,80'),
#  ('Next Generation Databases: Nosqland big Data (libro en Inglés)',
#   'Guy Harrison',
#   'S/ 388,56',
#   'S/ 271,99'),
#  ('Analítica De Datos: La Guía Definitiva De Análisis De Big Data Para Empresas, Técnicas De Minería De Datos, Recopilación De Datos Y Conceptos De Inteligencia Empresarial (spanish Edition)',
#   'Herbert Jones',
#   'S/ 140,72',
#   'S/ 98,50'),
#  ('From Big Data To Artificial Intelligence 2019 Edition',
#   'David Vivancos',
#   'S/ 241,18',
#   'S/ 168,83'),
#  ("L'individu transparent: Dels raig X al big data (Col·lecció Argent Viu)",
#   'Xavier Duran Escriba',
#   'S/ 152,80',
#   'S/ 106,96'),
#  ('Big Data Analytics with SAS: Get actionable insights from your Big Data using the power of SAS',
#   'David Pope',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('The Intelligent Enterprise In The Era Of Big Data',
#   'Venkat Srinivasan',
#   'S/ 338,66',
#   'S/ 237,06'),
#  ('Big Data and Smart Service Systems (libro en Inglés)',
#   'Xiwei Liu',
#   'S/ 875,82',
#   'S/ 613,08'),
#  ('Nosql Data Models: Trends and Challenges (Computer Engineering: Databases and big Data) (libro en Inglés)',
#   'Olivier Pivert',
#   'S/ 828,55',
#   'S/ 579,98'),
#  ('Big Mechanisms in Systems Biology: Big Data Mining, Network Modeling, and Genome',
#   'Bor-Sen Chen Phd; Cheng-Wei Li',
#   'S/ 1.285,22',
#   'S/ 899,65'),
#  ('Big Data in India: Second Edition (libro en inglés)',
#   'Gerardus Blokdyk',
#   'S/ 542,17',
#   'S/ 379,52'),
#  ('Big Data Factories: Collaborative Approaches (Computational Social Sciences) (libro en Inglés)',
#   '',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Mars Applications in Geotechnical Engineering Systems: Multi',
#   'Wengang Zhang',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Data Governance Tools: Evaluation Criteria, Big Data Governance, and Alignment with Enterprise Data Management',
#   'Sunil Soares',
#   'S/ 351,55',
#   'S/ 246,09'),
#  ('Evolutionary Decision Trees in Large',
#   'Marek Kretowski',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Ciencia de los Datos: La Guía Definitiva Sobre Análisis de Datos, Minería de Datos, Almacenamiento de Datos, Visualización de Datos, big Data Para. Para Principiantes',
#   'Herbert Jones',
#   'S/ 194,43',
#   'S/ 136,10'),
#  ('Designing Data', 'Martin Kleppmann', 'S/ 351,72', 'S/ 246,20'),
#  ('Big Data in Ehealthcare: Challenges and Perspectives (libro en inglés)',
#   'Nandini Mukherjee; Sarmistha Neogy; Samiran Chattopadhyay',
#   'S/ 1.203,34',
#   'S/ 842,34'),
#  ("Business Intelligence: An Essential Beginner's Guide to bi, big Data, Artificial Intelligence, Cybersecurity, Machine Learning, Data Science, Data Analytics, Social Media and Internet Marketing (libro en Inglés)",
#   'Richard Hurley',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Practical Enterprise Data Lake Insights: Handle Data',
#   'Saurabh Gupta; Venkata Giri',
#   'S/ 351,72',
#   'S/ 246,20'),
#  ('Operations Research and Big Data: IO2015',
#   'XVII Congress Of Portuguese Association Of Operational Research (APDIO) (Studies In Big Data)',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Emerging Technology and Architecture for Big',
#   'Data Analytics',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Pentaho for Big Data Analytics', 'Manoj R Patil', 'S/ 384,47', 'S/ 269,13'),
#  ('Big Data, Datafizierung und Digitale Artefakte (libro en Alemán)',
#   '',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Matters of Life and Data: The Remarkable Journey of a big Data Visionary Whose Work Impacted Millions (Including You) (libro en Inglés)',
#   'Charles D. Morgan',
#   'S/ 179,61',
#   'S/ 125,72'),
#  ('Data Science For Beginners: This Book Includes',
#   'Leonard Deep',
#   'S/ 210,47',
#   'S/ 147,33'),
#  ('Camera Power: Proof, Policing, Privacy, and Audiovisual big Data (libro en Inglés)',
#   'Mary D. Fan',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Oracle Big Data Handbook (Oracle Press)',
#   'Tom Plunkett',
#   'S/ 376,36',
#   'S/ 263,45'),
#  ('Big Data Complete Self', 'Gerardus Blokdyk', 'S/ 542,17', 'S/ 379,52'),
#  ('Monitored: Business and Surveillance in a Time of big Data (libro en Inglés)',
#   'Peter Bloom',
#   'S/ 243,31',
#   'S/ 170,32'),
#  ('Cognitive Computing and Big Data Analytics',
#   'Judith Hurwitz',
#   'S/ 339,28',
#   'S/ 237,50'),
#  ('Using Big Data for business perspectives',
#   'Singh Jaiteg',
#   'S/ 364,26',
#   'S/ 254,98'),
#  ('Big Data Management, Technologies, and Applications (Advances in Data Mining and Database Management)',
#   '',
#   'S/ 1.203,34',
#   'S/ 842,34'),
#  ('Privacy and big Data: The Players, Regulators, and Stakeholders (libro en Inglés)',
#   'Terence Craig; Mary E. Ludloff',
#   'S/ 187,96',
#   'S/ 131,57'),
#  ('Data Analytics and big Data (Information Systems, web and Pervasive Computing)',
#   'Soraya Sedkaoui',
#   'S/ 699,63',
#   'S/ 489,74'),
#  ('Una introducción al Big Data en Cirugía',
#   'Del Pozo Gil De Pareja Pablo',
#   'S/ 545,11',
#   'S/ 381,57'),
#  ('Data Modeling Made Simple with ER/Studio Data Architect: Adapting to Agile Data Modeling in a Big Data World',
#   'Steve Hoberman',
#   'S/ 351,55',
#   'S/ 246,09'),
#  ('Big Data Analytics con herramientas de SAS, IBM, Oracle y Microsoft',
#   'César Pérez',
#   'S/ 269,01',
#   'S/ 188,30'),
#  ('Web Microanalysis of Big Image Data',
#   'Peter Bajcsy',
#   'S/ 941,25',
#   'S/ 658,87'),
#  ('Big Data Analytics for Sustainable Computing (Advances in Data Mining and Database Management) (libro en Inglés)',
#   'Anandakumar Haldorai',
#   'S/ 1.945,56',
#   'S/ 1.361,89'),
#  ('Big Data Analytics for Sensor',
#   'Network Collected Intelligence (Intelligent Data',
#   'S/ 1.121,46',
#   'S/ 785,02'),
#  ('Big Data and Software Defined Networks (Computing and Networks) (libro en Inglés)',
#   '',
#   'S/ 1.060,05',
#   'S/ 742,04'),
#  ('Big Data Research for Social Sciences and Social Impact (libro en Inglés)',
#   '',
#   'S/ 570,58',
#   'S/ 399,41'),
#  ('Data Management and Analysis: Case Studies in Education, Healthcare and Beyond (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.236,01',
#   'S/ 865,21'),
#  ('Big Data', 'Puneet Goswami', 'S/ 454,68', 'S/ 318,28'),
#  ('Planning 2020: Estrategia, Eficacia, Innovación, big Data y Gestión de Marcas en un Entorno Digital',
#   'Desconocido',
#   'S/ 271,60',
#   'S/ 190,12'),
#  ('Przegląd narzędzi Big Data do analizy rozproszonych danych o kliencie: Porównanie narzędzi Big Data do analizy rozproszonych danych o konsumencie w ... przedsiębiorstwach (Polish Edition)',
#   'Aleksandra Woźniak',
#   'S/ 261,31',
#   'S/ 182,92'),
#  ('Predictive Econometrics and big Data (Studies in Computational Intelligence) (libro en Inglés)',
#   '',
#   'S/ 3.741,51',
#   'S/ 2.619,06'),
#  ('Collecting Experiments: Making big Data Biology (libro en Inglés)',
#   'Bruno J. Strasser',
#   'S/ 425,49',
#   'S/ 297,84'),
#  ('Artificial Intelligence big Data Gathering: Function (libro en inglés)',
#   'Johnny Ch Lok',
#   'S/ 787,80',
#   'S/ 551,46'),
#  ('Big Data',
#   'Enabled Internet Of Things (Computing And Networks) (libro En Inglés)',
#   'S/ 1.002,74',
#   'S/ 701,92'),
#  ('Big Data for Chimps: A Guide to Massive',
#   'Philip Kromer',
#   'S/ 318,96',
#   'S/ 223,28'),
#  ('Big Data Science in Finance (libro en Inglés)',
#   'Irene Aldridge; M. Avellaneda',
#   'S/ 725,50',
#   'S/ 507,85'),
#  ('Making big Data Work for Your Business (libro en Inglés)',
#   'Sudhi Sinha',
#   'S/ 353,16',
#   'S/ 247,21'),
#  ('Artificial Intelligence for big Data (libro en Inglés)',
#   'Anand Deshpande; Manish Kumar',
#   'S/ 439,46',
#   'S/ 307,63'),
#  ('Big Data Recommender Systems: Application Paradigms (Computing and Networks) (libro en Inglés)',
#   '',
#   'S/ 1.031,40',
#   'S/ 721,98'),
#  ('Whither Turbulence and big Data in the 21St Century? (libro en Inglés)',
#   '',
#   'S/ 1.899,23',
#   'S/ 1.329,46'),
#  ('La Protección de Datos de Carácter Sensible: Historia Clinica Digital y big Data en Salud',
#   'Luc&Iacute;A Cristea Uivaru',
#   'S/ 313,77',
#   'S/ 219,64'),
#  ('Analytics and Big Data for Accountants (AICPA) (libro en Inglés)',
#   'Jim Lindell',
#   'S/ 671,25',
#   'S/ 469,87'),
#  ('Whither Turbulence and big Data in the 21St Century? (libro en Inglés)',
#   '',
#   'S/ 1.899,23',
#   'S/ 1.329,46'),
#  ('Introducing Data Science: Big Data, Machine Learning, and more, using Python tools',
#   'Davy Cielen',
#   'S/ 351,72',
#   'S/ 246,20'),
#  ('Processing Big Data with Azure HDInsight: Building Real',
#   'Vinit Yadav',
#   'S/ 388,56',
#   'S/ 271,99'),
#  ('Linked Data Visualization: Techniques, Tools, and big Data (Synthesis Lectures on Data, Semantics, and Knowledge) (libro en Inglés)',
#   'Laura Po; Nikos Bikakis; Federico Desimoni',
#   'S/ 616,76',
#   'S/ 431,73'),
#  ('The Billion Dollar Byte: Turn big Data Into Good Profits, the Datapreneur way (libro en inglés)',
#   'D. Justhy',
#   'S/ 145,22',
#   'S/ 101,65'),
#  ('Analítica de Datos: Una Guía Esencial Para Principiantes en Minería de Datos, Recolección de Datos, Análisis de big Data Para Negocios y Conceptos de Inteligencia Empresarial',
#   'Herbert Jones',
#   'S/ 184,94',
#   'S/ 129,46'),
#  ('Big Data for Analysts: Invent the future',
#   'Yevgen Bilous',
#   'S/ 630,11',
#   'S/ 441,07'),
#  ('Big Data Science & Analytics: A Hands',
#   'Arshdeep Bahga',
#   'S/ 424,69',
#   'S/ 297,28'),
#  ('Pro Hadoop Data Analytics: Designing and Building big Data Systems Using the Hadoop Ecosystem (libro en Inglés)',
#   'Kerry Koitzsch',
#   'S/ 366,45',
#   'S/ 256,52'),
#  ('Predictive Analytics, Data Mining And Big Data: Myths, Misconceptions And Methods (business In The Digital Economy)',
#   'S. Finlay',
#   'S/ 404,94',
#   'S/ 283,46'),
#  ('New Horizons for a Data',
#   'Driven Economy: A Roadmap For Usage And Exploitation Of Big Data In Europe (libro En Inglés)',
#   'S/ 499,10',
#   'S/ 349,37'),
#  ('BDMOT Theory (Big Data Moment Of Truth): The impact of Big Data and related technology on Business decisions',
#   'Moulay El Mehdi Sarsar',
#   'S/ 448,42',
#   'S/ 313,89'),
#  ('Efficient and Reliable Cloud Architecture for Big Data Handling',
#   'Tarannum Narzu',
#   'S/ 261,31',
#   'S/ 182,92'),
#  ('Big Data Analytics in Bioinformatics and Healthcare',
#   'Baoying Wang',
#   'S/ 1.727,37',
#   'S/ 1.209,16'),
#  ('Big Data for Qualitative Research (libro en Inglés)',
#   'Kathy A. Mills',
#   'S/ 589,25',
#   'S/ 412,47'),
#  ('Thinking Big Data in Geography: New Regimes, New Research',
#   '',
#   'S/ 609,72',
#   'S/ 426,80'),
#  ("Exploring big Historical Data: The Historian's Macroscope",
#   'Shawn Graham',
#   'S/ 338,84',
#   'S/ 237,19'),
#  ('Blockchain Technology and big Data Analytics (libro en Inglés)',
#   'Kumar',
#   'S/ 1.240,10',
#   'S/ 868,07'),
#  ('Biomedical Informatics: Discovering Knowledge in Big Data',
#   'Andreas Holzinger',
#   'S/ 941,25',
#   'S/ 658,87'),
#  ('Disk', 'Christopher G. Healey', 'S/ 710,02', 'S/ 497,01'),
#  ('Modern Big Data Processing with Hadoop',
#   'V Naresh Kumar',
#   'S/ 384,47',
#   'S/ 269,13'),
#  ('Strategic Engineering for Cloud Computing and Big Data Analytics',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Spatial Data Handling in big Data Era: Select Papers From the 17Th igu Spatial Data Handling Symposium 2016 (Advances in Geographic Information Science) (libro en Inglés)',
#   '',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('The age of ai: An Introduction to big Data, Machine Learning, and Neural Networks (libro en Inglés)',
#   'Marc Stanford',
#   'S/ 134,08',
#   'S/ 93,86'),
#  ('Sharing Economy and big Data Analytics (libro en Inglés)',
#   'Soraya Sedkaoui; Mounia Khelfaoui',
#   'S/ 828,55',
#   'S/ 579,98'),
#  ('Big Data Analytics for Large',
#   'Stefanos Vrochidis',
#   'S/ 765,88',
#   'S/ 536,11'),
#  ('Artificial Intelligence big Data Travelling Consumption Prediction (libro en inglés)',
#   'Johnny Ch Lok',
#   'S/ 732,54',
#   'S/ 512,78'),
#  ('Big Data for Managers: Creating Value (libro en Inglés)',
#   'Atal Malviya; Mike Malmgren',
#   'S/ 1.326,16',
#   'S/ 928,31'),
#  ('To the Cloud: Big Data in a Turbulent World (libro en inglés)',
#   'Vincent Mosco',
#   'S/ 416,89',
#   'S/ 291,82'),
#  ('Handbook of iot and big Data (Science, Technology, and Management) (libro en Inglés)',
#   '',
#   'S/ 1.571,39',
#   'S/ 1.099,97'),
#  ('Decentralised Internet of Things: A Blockchain Perspective (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Authentication Technologies for Cloud Computing, iot and big Data (Security) (libro en Inglés)',
#   '',
#   'S/ 974,08',
#   'S/ 681,86'),
#  ('Data Visualization and Statistical Literacy for Open and Big Data (Advances in Data Mining and Database Management)',
#   'Theodosia Prodromou',
#   'S/ 1.651,63',
#   'S/ 1.156,14'),
#  ('The Big Data Agenda: Data Ethics and Critical Data Studies (Critical Digital and Social Media Studies Series)',
#   'Annika Richterich',
#   'S/ 506,43',
#   'S/ 354,50'),
#  ('Recruiting 4. 0', 'Kevin William Der', 'S/ 259,19', 'S/ 181,44'),
#  ('Big Data in Context: Legal, Social and Technological Insights (SpringerBriefs in Law)',
#   '',
#   'S/ 241,18',
#   'S/ 168,83'),
#  ('Web Data Mining: Exploring Hyperlinks, Contents, and Usage Data (Data',
#   'Bing Liu',
#   'S/ 720,17',
#   'S/ 504,12'),
#  ('Big Data in Medical Science and Healthcare Management (libro en Inglés)',
#   'Peter Langkafel',
#   'S/ 830,79',
#   'S/ 581,55'),
#  ('Handbook of big Data Analytics (Springer Handbooks of Computational Statistics) (libro en Inglés)',
#   '',
#   'S/ 2.636,14',
#   'S/ 1.845,30'),
#  ('Big Data Information Management for Government: A Complete Guide (libro en inglés)',
#   'Gerardus Blokdyk',
#   'S/ 542,17',
#   'S/ 379,52'),
#  ('Big Data at Work: The Data Science Revolution and Organizational Psychology (SIOP Organizational Frontiers Series)',
#   '',
#   'S/ 654,34',
#   'S/ 458,04'),
#  ('Framing big Data: A Linguistic and Discursive Approach (libro en Inglés)',
#   'Maria Cristina Paganoni',
#   'S/ 499,10',
#   'S/ 349,37'),
#  ('Complete Guide to Open Source big Data Stack (libro en Inglés)',
#   'Michael Frampton',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Getting Started With Greenplum for big Data Analytics (libro en Inglés)',
#   'Sunila Gollapudi',
#   'S/ 415,29',
#   'S/ 290,70'),
#  ('Machine Learning for big Data Analyis (Frontiers in Computational Intelligence) (libro en Inglés)',
#   '',
#   'S/ 998,56',
#   'S/ 698,99'),
#  ('Reasons Need Artificial Intelligence big Data Gathering (libro en Inglés)',
#   'Johnny Ch Lok',
#   'S/ 1.033,44',
#   'S/ 723,41'),
#  ('Deep Learning and Missing Data in Engineering Systems (Studies in big Data) (libro en Inglés)',
#   'Collins Achepsah Leke; Tshilidzi Marwala',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Big Data and Analytics: Strategic and Organizational Impacts (libro en Inglés)',
#   'Vincenzo Morabito',
#   'S/ 572,79',
#   'S/ 400,95'),
#  ('Loyalty 3.0: How to Revolutionize Customer and Employee Engagement with Big Data and Gamification',
#   'Paharia, Rajat',
#   'S/ 204,25',
#   'S/ 142,98'),
#  ('The Visual Organization: Data Visualization, Big Data, And The Quest For Better Decisions',
#   'Phil Simon',
#   'S/ 339,28',
#   'S/ 237,50'),
#  ('Managing and Processing Big Data in Cloud Computing (Advances in Data Mining and Database Management)',
#   '',
#   'S/ 1.367,10',
#   'S/ 956,97'),
#  ('Service Model for Big Data Applications in the Cloud',
#   'Devang Swami',
#   'S/ 280,11',
#   'S/ 196,08'),
#  ('Data',
#   'Organization For Economic Co-Operation A',
#   'S/ 1.140,29',
#   'S/ 798,21'),
#  ('Data Mining for Managers: How to use Data (Big and Small) to Solve Business Challenges (libro en Inglés)',
#   'R. Boire',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Big Data in the Arts and Humanities: Theory and Practice (Data Analytics Applications) (libro en inglés)',
#   'Giovanni Schiuma; Daniela Carlucci',
#   'S/ 1.203,34',
#   'S/ 842,34'),
#  ('Big Data Analytics Methods: Analytics Techniques in Data Mining, Deep Learning and Natural Language Processing (libro en Inglés)',
#   'Peter Ghavami',
#   'S/ 548,23',
#   'S/ 383,76'),
#  ('Towards Analytical Techniques for Optimizing Knowledge Acquisition, Processing, Propagation, and Use in Cyberinfrastructure and Big Data (Studies in Big Data)',
#   'L. Octavio Lerma',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Business unIntelligence: Insight and Innovation beyond Analytics and Big Data',
#   'Barry Devlin',
#   'S/ 253,30',
#   'S/ 177,31'),
#  ('Big Data Beyond the Hype: A Guide to Conversations for Today’S Data Center (Database & erp',
#   'Paul Zikopoulos; Dirk Deroos; Christopher Bienko; Marc Andrews; Rick Buglio',
#   'S/ 165,11',
#   'S/ 115,58'),
#  ('Transactions on Large', 'Scale Data', 'S/ 535,94', 'S/ 375,16'),
#  ('Big Data: Die Revolution, Die Unser Leben Verändern Wird',
#   'Viktor Mayer-schönberger,kenneth Cukier',
#   'S/ 207,05',
#   'S/ 144,94'),
#  ('Linked Data Visualization: Techniques, Tools, and big Data (Synthesis Lectures on Data, Semantics, and Knowledge) (libro en Inglés)',
#   'Laura Po; Nikos Bikakis; Federico Desimoni; George Papastefanatos',
#   'S/ 469,70',
#   'S/ 328,79'),
#  ('We Are Big Data: The Future Of The Information Society',
#   'Sander Klous,nart Wielaard',
#   'S/ 278,03',
#   'S/ 194,62'),
#  ('Big Data Science in Finance (libro en Inglés)',
#   'Irene Aldridge; M. Avellaneda',
#   'S/ 725,50',
#   'S/ 507,85'),
#  ('Matters of Life and Data: The Remarkable Journey of a big Data Visionary Whose Work Impacted Millions (Including You) (libro en Inglés)',
#   'Charles D. Morgan',
#   'S/ 253,30',
#   'S/ 177,31'),
#  ('Big Data, big Innovation: Enabling Competitive Differentiation Through Business Analytics (Wiley and sas Business Series) (libro en Inglés)',
#   'Evan Stubbs',
#   'S/ 371,45',
#   'S/ 260,01'),
#  ('Everybody Lies: Big Data, New Data, and What the Internet Can Tell Us About Who We Really Are',
#   'Seth Stephens-Davidowitz',
#   'S/ 217,43',
#   'S/ 152,20'),
#  ('B4B: How Technology and Big Data are Reinventing the Customer',
#   'J. B. Wood',
#   'S/ 179,61',
#   'S/ 125,72'),
#  ('Thinking Ahead', 'Dirk Helbing', 'S/ 204,33', 'S/ 143,03'),
#  ("The art of Invisibility: The World's Most Famous Hacker Teaches you how to be Safe in the age of big Brother and big Data (libro en Inglés)",
#   'Kevin Mitnick',
#   'S/ 145,38',
#   'S/ 101,77'),
#  ('Big Data Applications in the Telecommunications Industry (Research Essentials Collection)',
#   '',
#   'S/ 1.184,92',
#   'S/ 829,44'),
#  ('Practical Concurrent Haskell: With Big Data Applications',
#   'Stefania Loredana Nita',
#   'S/ 388,56',
#   'S/ 271,99'),
#  ('Dementia Research And Care:: Can Big Data Help? (Volume 2015)',
#   '',
#   'S/ 366,54',
#   'S/ 256,58'),
#  ('Big',
#   'Data Analytics And Cloud Computing: Theory, Algorithms And Applications',
#   'S/ 941,25',
#   'S/ 658,87'),
#  ('The Human Element of Big Data: Issues, Analytics, and Performance',
#   '',
#   'S/ 1.262,70',
#   'S/ 883,89'),
#  ('Beginning Apache Pig: Big Data Processing Made Easy',
#   'Balaswamy Vaddeman',
#   'S/ 336,98',
#   'S/ 235,88'),
#  ('Geo', 'Burçin Bozkaya', 'S/ 1.459,35', 'S/ 1.021,54'),
#  ('Alternative Data: Capturing the Predictive Power of Big Data for Investment Success (Wiley Trading)',
#   'Mani Mahjouri',
#   'S/ 338,66',
#   'S/ 237,06'),
#  ('Humanizing Big Data: Marketing at the Meeting of Data, Social Science and Consumer Insight',
#   'Colin Strong',
#   'S/ 543,15',
#   'S/ 380,20'),
#  ('Stream Data Mining: Algorithms and Their Probabilistic Properties (Studies in big Data) (libro en Inglés)',
#   'Leszek Rutkowski; Maciej Jaworski; Piotr Duda',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Predictive Analytics, Data Mining and big Data: Myths, Misconceptions and Methods (Business in the Digital Economy) (libro en Inglés)',
#   'S. Finlay',
#   'S/ 370,14',
#   'S/ 259,10'),
#  ('Big', 'Kai Hwang', 'S/ 609,21', 'S/ 426,44'),
#  ('Learning big Data With Amazon Elastic Mapreduce (libro en Inglés)',
#   'Amarkant Singh; Vijay Rayapati',
#   'S/ 464,98',
#   'S/ 325,49'),
#  ('Ubiquitous Computing and Computing Security of iot (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Professional Spark: Big Data Cluster Computing in Production',
#   'Ema Iancuta',
#   'S/ 339,28',
#   'S/ 237,50'),
#  ('Algorithmic Life: Calculative Devices in the Age of Big Data',
#   '',
#   'S/ 1.448,98',
#   'S/ 1.014,29'),
#  ('Algorithmic Life: Calculative Devices in the Age of Big Data',
#   '',
#   'S/ 588,84',
#   'S/ 412,19'),
#  ('Chancen und Risiken von Big Data in Smart Cities am Fallbeispiel Songdo',
#   'Ann-Kristin Mehnert',
#   'S/ 179,20',
#   'S/ 125,44'),
#  ('Big Data Marketing: Engage Your Customers More Effectively And Drive Value',
#   'Lisa Arthur',
#   'S/ 236,24',
#   'S/ 165,37'),
#  ('Entity Information Life Cycle for Big Data: Master Data Management and Information Integration',
#   'John R. Talburt',
#   'S/ 588,84',
#   'S/ 412,19'),
#  ('Das Ende des Zufalls: Wie Big Data uns und unser Leben vorhersagbar macht',
#   'Rudi Klausnitzer',
# ...
#  ('Big Data for Managers (libro en Inglés)',
#   'Atal Malviya',
#   'S/ 515,15',
#   'S/ 360,60'),
#  ('Analítica de Datos: La Guía Definitiva de Análisis de big Data Para Empresas, Técnicas de Minería de Datos, Recopilación de Datos y Conceptos de Inteligencia Empresarial',
#   'Herbert Jones',
#   'S/ 194,43',
#   'S/ 136,10'),
#  ('Cloud Computing for Geospatial big Data Analytics: Intelligent Edge, fog and Mist Computing (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Analytics on the Cloud: An end', 'Sanket Thodge', 'S/ 382,91', 'S/ 268,04'),
#  ('Big Data: Conceptos, Tecnologías y Aplicaciones: 108 (¿ Qué Sabemos De? )',
#   'David R&Iacute;Os Insua; David G&Oacute;Mez-Ullate Oteiza',
#   'S/ 114,04',
#   'S/ 79,83'),
#  ('Big Data, Cloud Computing, Data Science & Engineering (Studies in Computational Intelligence) (libro en Inglés)',
#   '',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Astronomy and Big Data: A Data Clustering Approach to Identifying Uncertain Galaxy Morphology (Studies in Big Data)',
#   'Kieran Jay Edwards',
#   'S/ 1.236,01',
#   'S/ 865,21'),
#  ('Big Data Analytics: Methods and Applications (libro en Inglés)',
#   '',
#   'S/ 793,86',
#   'S/ 555,70'),
#  ('Big Data Analytics (Database Management Systems) (libro en Inglés)',
#   '',
#   'S/ 945,42',
#   'S/ 661,80'),
#  ('Big Data In Practice: How 45 Successful Companies Used Big Data Analytics To Deliver Extraordinary Results',
#   'Wiley',
#   'S/ 285,66',
#   'S/ 199,96'),
#  ('Big Data, Big Value ?: Antagonisme ou complémentarité ? (French Edition)',
#   'Najoie Hami-Eddine',
#   'S/ 261,31',
#   'S/ 182,92'),
#  ('Talend for big Data (libro en Inglés)',
#   'Bahaaldine Azarmi',
#   'S/ 363,81',
#   'S/ 254,67'),
#  ('Big Data, Health Law, and Bioethics (libro en Inglés)',
#   '',
#   'S/ 613,73',
#   'S/ 429,61'),
#  ('Advances in Mobile Cloud Computing and Big Data in the 5G Era (Studies in Big Data)',
#   '',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Simulación de Redes Neuronales Como Herramienta big Data en el Ámbito Sanitario',
#   'Marcos Redondo Fonseca',
#   'S/ 278,94',
#   'S/ 195,26'),
#  ('Big Data: Does Size Matter? (Bloomsbury Sigma)',
#   'Timandra Harkness',
#   'S/ 211,78',
#   'S/ 148,25'),
#  ('Strategic Data', 'John Girard', 'S/ 1.399,85', 'S/ 979,90'),
#  ('Practical Big Data Analytics',
#   'Nataraj Dasgupta',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Using R to Unlock the Value of Big Data: Big Data Analytics with Oracle R Enterprise and Oracle R Connector for Hadoop',
#   'Mark Hornick',
#   'S/ 179,85',
#   'S/ 125,90'),
#  ('BIG DATA EN EDUCACION. EL FUTURO DIGITAL DEL APRENDIZAJE, LA',
#   'BEN WILLIAMSON',
#   'S/ 256,83',
#   'S/ 179,78'),
#  ('Data Versus Democracy: How big Data Algorithms Shape Opinions and Alter the Course of History (libro en Inglés)',
#   'Kris Shaffer',
#   'S/ 194,51',
#   'S/ 136,16'),
#  ('Too big to Ignore: The Business Case for big Data (Wiley and sas Business Series) (libro en inglés)',
#   'Phil Simon',
#   'S/ 186,55',
#   'S/ 130,59'),
#  ('The Big Data Agenda: Data Ethics and Critical Data Studies (Critical Digital and Social Media Studies Series)',
#   'Annika Richterich',
#   'S/ 223,35',
#   'S/ 156,34'),
#  ('Advances in Data Science: Symbolic, Complex, and Network Data (Innovation, Entrepreneurship, Management; Big Data, Intelligence and Data Analaysis) (libro en Inglés)',
#   'Diday',
#   'S/ 828,55',
#   'S/ 579,98'),
#  ('Metaheuristics for Big Data (Computer Engineering Series: Metaheuristics Set)',
#   'Clarisse Dhaenens',
#   'S/ 644,21',
#   'S/ 450,95'),
#  ('Highlighting the Importance of Big Data Management and Analysis for Various Applications (Studies in Big Data)',
#   '',
#   'S/ 867,56',
#   'S/ 607,29'),
#  ('Big Data Processing', 'Dr. M. Mohemmed Sha Dr.', 'S/ 671,13', 'S/ 469,79'),
#  ('Big Data Analytics Using Splunk: Deriving Operational Intelligence From Social Media, Machine Data, Existing Data Warehouses, and Other Real',
#   'Peter Zadrozny',
#   'S/ 388,56',
#   'S/ 271,99'),
#  ('Next generation computing and big data analytics',
#   'United States Congress',
#   'S/ 198,19',
#   'S/ 138,74'),
#  ('Big data and agriculture : innovation and implications',
#   'United States Congress',
#   'S/ 198,19',
#   'S/ 138,74'),
#  ('Data Science Landscape: Towards Research Standards and Protocols (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('The Enterprise big Data Lake (libro en Inglés)',
#   'Alex Gorelik',
#   'S/ 400,84',
#   'S/ 280,59'),
#  ('The Big Book of Dashboards: Visualizing Your Data Using Real',
#   'Steve Wexler',
#   'S/ 275,76',
#   'S/ 193,03'),
#  ('Big Data Computing: A Guide for Business and Technology Managers (Chapman & Hall/CRC Big Data Series)',
#   'Vivek Kale',
#   'S/ 1.571,80',
#   'S/ 1.100,26'),
#  ('Numbersense: How to use big Data to Your Advantage (libro en Inglés)',
#   'Kaiser Fung',
#   'S/ 194,10',
#   'S/ 135,87'),
#  ('Big Data Approach for Anomaly Detection',
#   'Namrata Verma',
#   'S/ 280,11',
#   'S/ 196,08'),
#  ('Predictive Analytics: The Secret to Predicting Future Events Using big Data and Data Science Techniques Such as Data Mining, Predictive Modelling, Statistics, Data Analysis, and Machine Learning (libro en Inglés)',
#   'Richard Hurley',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Big Data Integration (Synthesis Lectures on Data Management)',
#   'Xin Luna Dong',
#   'S/ 536,03',
#   'S/ 375,22'),
#  ('Privacy, big Data, and the Public Good (libro en Inglés)',
#   '',
#   'S/ 752,92',
#   'S/ 527,05'),
#  ('Big Data, Health Law, and Bioethics (libro en Inglés)',
#   'Cohen',
#   'S/ 1.228,19',
#   'S/ 859,73'),
#  ('Scaling Big Data With Hadoop And Solr',
#   'Hrishikesh Karambelkar',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Big Data and Business Analytics (libro en inglés)',
#   'Liebowitz. Jay',
#   'S/ 703,47',
#   'S/ 492,43'),
#  ('Big Data Privacy: A Complete Guide (libro en inglés)',
#   'Gerardus Blokdyk',
#   'S/ 542,17',
#   'S/ 379,52'),
#  ('Big Data, Open Data and Data Development',
#   'Jean-Louis Monino',
#   'S/ 563,46',
#   'S/ 394,42'),
#  ('Next', 'Butch Quinto', 'S/ 253,46', 'S/ 177,42'),
#  ('Big Data: A Revolution That Will Transform How We Live, Work, And Think',
#   'Viktor Mayer-schönberger,kenneth Cukier',
#   'S/ 135,39',
#   'S/ 94,77'),
#  ('Data Science and big Data Analytics: Acm',
#   'Wir 2018 (Lecture Notes On Data Engineering And Communications Technologies) (libro En Inglés)',
#   'S/ 1.678,16',
#   'S/ 1.174,71'),
#  ("Big Data Imperatives: Enterprise 'big Data' Warehouse, 'bi' Implementations and Analytics (The Expert's Voice) (libro en Inglés)",
#   'Soumendra Mohanty; Madhu Jagadeesh; Harsha Srivatsa',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Weapons of Math Destruction: How Big Data Increases Inequality and Threatens Democracy',
#   "CATHY O'NEIL",
#   'S/ 118,42',
#   'S/ 82,90'),
#  ('Big Data Technologies and Applications',
#   'Borko Furht',
#   'S/ 1.236,01',
#   'S/ 865,21'),
#  ('Conquering Big Data with High Performance Computing',
#   '',
#   'S/ 1.530,78',
#   'S/ 1.071,54'),
#  ('Analítica De Datos: Una Guía Esencial Para Principiantes En Minería De Datos, Recolección De Datos, Análisis De Big Data Para Negocios Y Conceptos De Inteligencia Empresarial (spanish Edition)',
#   'Herbert Jones',
#   'S/ 138,91',
#   'S/ 97,24'),
#  ('Big Data and Official Statistics',
#   'Carlo Vaccari',
#   'S/ 400,07',
#   'S/ 280,05'),
#  ('Big Data Analysen (libro en Alemán)',
#   'Sebastian Muller',
#   'S/ 413,13',
#   'S/ 289,19'),
#  ('Reinventing Capitalism in the Age of Big Data',
#   'Viktor Mayer-Schnberger',
#   'S/ 191,56',
#   'S/ 134,09'),
#  ('Thinking big Data in Geography: New Regimes, new Research (libro en inglés)',
#   '',
#   'S/ 278,11',
#   'S/ 194,67'),
#  ('Big data and agriculture : innovation in the air',
#   'United States Congress',
#   'S/ 198,19',
#   'S/ 138,74'),
#  ('Integration von Big Data Technologien in ein Enterprise Data Warehouse',
#   'Loer Philipp',
#   'S/ 400,07',
#   'S/ 280,05'),
#  ('Beginning big Data With Power bi and Excel 2013: Big Data Processing and Analysis Using Powerbi in Excel 2013 (libro en Inglés)',
#   'Neil Dunlop',
#   'S/ 351,72',
#   'S/ 246,20'),
#  ('Data Strategy and the Enterprise Data Executive: Ensuring that Business and IT are in Synch in the Post',
#   'Peter Aiken',
#   'S/ 210,10',
#   'S/ 147,07'),
#  ('Big Data Forensics – Learning Hadoop Investigations (libro en Inglés)',
#   'Joe Sremack',
#   'S/ 466,59',
#   'S/ 326,61'),
#  ("Big Data: A Beginner's Introduction (libro en Inglés)",
#   'Saswat Sarangi; Pankaj Sharma',
#   'S/ 425,08',
#   'S/ 297,56'),
#  ('Big Data in Predictive Toxicology (Issues in Toxicology) (libro en Inglés)',
#   '',
#   'S/ 1.796,97',
#   'S/ 1.257,88'),
#  ('Big Data A Tool for Inclusion or Exclusion? Understanding the Issues',
#   'Federal Trade Commission',
#   'S/ 136,54',
#   'S/ 95,58'),
#  ('Madison Miles and the Big, Big Move',
#   'Dara Nichole',
#   'S/ 155,29',
#   'S/ 108,70'),
#  ('Systems Analytics and Integration of big Omics Data (libro en Inglés)',
#   '',
#   'S/ 431,14',
#   'S/ 301,80'),
#  ('Next Generation Databases: Nosqland big Data (libro en Inglés)',
#   'Guy Harrison',
#   'S/ 388,56',
#   'S/ 271,99'),
#  ('Analítica De Datos: La Guía Definitiva De Análisis De Big Data Para Empresas, Técnicas De Minería De Datos, Recopilación De Datos Y Conceptos De Inteligencia Empresarial (spanish Edition)',
#   'Herbert Jones',
#   'S/ 140,72',
#   'S/ 98,50'),
#  ('From Big Data To Artificial Intelligence 2019 Edition',
#   'David Vivancos',
#   'S/ 241,18',
#   'S/ 168,83'),
#  ("L'individu transparent: Dels raig X al big data (Col·lecció Argent Viu)",
#   'Xavier Duran Escriba',
#   'S/ 152,80',
#   'S/ 106,96'),
#  ('Big Data Analytics with SAS: Get actionable insights from your Big Data using the power of SAS',
#   'David Pope',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('The Intelligent Enterprise In The Era Of Big Data',
#   'Venkat Srinivasan',
#   'S/ 338,66',
#   'S/ 237,06'),
#  ('Big Data and Smart Service Systems (libro en Inglés)',
#   'Xiwei Liu',
#   'S/ 875,82',
#   'S/ 613,08'),
#  ('Nosql Data Models: Trends and Challenges (Computer Engineering: Databases and big Data) (libro en Inglés)',
#   'Olivier Pivert',
#   'S/ 828,55',
#   'S/ 579,98'),
#  ('Big Mechanisms in Systems Biology: Big Data Mining, Network Modeling, and Genome',
#   'Bor-Sen Chen Phd; Cheng-Wei Li',
#   'S/ 1.285,22',
#   'S/ 899,65'),
#  ('Big Data in India: Second Edition (libro en inglés)',
#   'Gerardus Blokdyk',
#   'S/ 542,17',
#   'S/ 379,52'),
#  ('Big Data Factories: Collaborative Approaches (Computational Social Sciences) (libro en Inglés)',
#   '',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Data Governance Tools: Evaluation Criteria, Big Data Governance, and Alignment with Enterprise Data Management',
#   'Sunil Soares',
#   'S/ 351,55',
#   'S/ 246,09'),
#  ('Evolutionary Decision Trees in Large',
#   'Marek Kretowski',
#   'S/ 1.162,32',
#   'S/ 813,62'),
#  ('Ciencia de los Datos: La Guía Definitiva Sobre Análisis de Datos, Minería de Datos, Almacenamiento de Datos, Visualización de Datos, big Data Para. Para Principiantes',
#   'Herbert Jones',
#   'S/ 194,43',
#   'S/ 136,10'),
#  ('Designing Data', 'Martin Kleppmann', 'S/ 351,72', 'S/ 246,20'),
#  ('Big Data in Ehealthcare: Challenges and Perspectives (libro en inglés)',
#   'Nandini Mukherjee; Sarmistha Neogy; Samiran Chattopadhyay',
#   'S/ 1.203,34',
#   'S/ 842,34'),
#  ("Business Intelligence: An Essential Beginner's Guide to bi, big Data, Artificial Intelligence, Cybersecurity, Machine Learning, Data Science, Data Analytics, Social Media and Internet Marketing (libro en Inglés)",
#   'Richard Hurley',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Practical Enterprise Data Lake Insights: Handle Data',
#   'Saurabh Gupta; Venkata Giri',
#   'S/ 351,72',
#   'S/ 246,20'),
#  ('Operations Research and Big Data: IO2015',
#   'XVII Congress Of Portuguese Association Of Operational Research (APDIO) (Studies In Big Data)',
#   'S/ 1.309,70',
#   'S/ 916,79'),
#  ('Emerging Technology and Architecture for Big',
#   'Data Analytics',
#   'S/ 1.383,39',
#   'S/ 968,38'),
#  ('Pentaho for Big Data Analytics', 'Manoj R Patil', 'S/ 384,47', 'S/ 269,13'),
#  ('Big Data, Datafizierung und Digitale Artefakte (libro en Alemán)',
#   '',
#   'S/ 425,41',
#   'S/ 297,79'),
#  ('Matters of Life and Data: The Remarkable Journey of a big Data Visionary Whose Work Impacted Millions (Including You) (libro en Inglés)',
#   'Charles D. Morgan',
#   'S/ 179,61',
#   'S/ 125,72'),
#  ('Data Science For Beginners: This Book Includes',
#   'Leonard Deep',
#   'S/ 210,47',
#   'S/ 147,33'),
#  ('Camera Power: Proof, Policing, Privacy, and Audiovisual big Data (libro en Inglés)',
#   'Mary D. Fan',
#   'S/ 204,33',
#   'S/ 143,03'),
#  ('Oracle Big Data Handbook (Oracle Press)',
#   'Tom Plunkett',
#   'S/ 376,36',
#   'S/ 263,45'),
#  ('Big Data Complete Self', 'Gerardus Blokdyk', 'S/ 542,17', 'S/ 379,52'),
#  ('Monitored: Business and Surveillance in a Time of big Data (libro en Inglés)',
#   'Peter Bloom',
#   'S/ 243,31',
#   'S/ 170,32'),
#  ('Cognitive Computing and Big Data Analytics',
#   'Judith Hurwitz',
#   'S/ 339,28',
#   'S/ 237,50'),
#  ('Using Big Data for business perspectives',
#   'Singh Jaiteg',
#   'S/ 364,26',
#   'S/ 254,98'),
#  ('Big Data Management, Technologies, and Applications (Advances in Data Mining and Database Management)',
#   '',
#   'S/ 1.203,34',
#   'S/ 842,34'),
#  ('Privacy and big Data: The Players, Regulators, and Stakeholders (libro en Inglés)',
#   'Terence Craig; Mary E. Ludloff',
#   'S/ 187,96',
#   'S/ 131,57'),
#  ('Data Analytics and big Data (Information Systems, web and Pervasive Computing)',
#   'Soraya Sedkaoui',
#   'S/ 699,63',
#   'S/ 489,74'),
#  ('Una introducción al Big Data en Cirugía',
#   'Del Pozo Gil De Pareja Pablo',
#   'S/ 545,11',
#   'S/ 381,57'),
#  ('Data Modeling Made Simple with ER/Studio Data Architect: Adapting to Agile Data Modeling in a Big Data World',
#   'Steve Hoberman',
#   'S/ 351,55',
#   'S/ 246,09'),
#  ('Big Data Analytics con herramientas de SAS, IBM, Oracle y Microsoft',
#   'César Pérez',
#   'S/ 269,01',
#   'S/ 188,30'),
#  ('Web Microanalysis of Big Image Data',
#   'Peter Bajcsy',
#   'S/ 941,25',
#   'S/ 658,87'),
#  ('Big Data Analytics for Sustainable Computing (Advances in Data Mining and Database Management) (libro en Inglés)',
#   'Anandakumar Haldorai',
#   'S/ 1.945,56',
#   'S/ 1.361,89'),
#  ('Big Data Analytics for Sensor',
#   'Network Collected Intelligence (Intelligent Data',
#   'S/ 1.121,46',
#   'S/ 785,02'),
#  ('Big Data and Software Defined Networks (Computing and Networks) (libro en Inglés)',
#   '',
#   'S/ 1.060,05',
#   'S/ 742,04'),
#  ('Big Data Research for Social Sciences and Social Impact (libro en Inglés)',
#   '',
#   'S/ 570,58',
#   'S/ 399,41'),
#  ('Data Management and Analysis: Case Studies in Education, Healthcare and Beyond (Studies in big Data) (libro en Inglés)',
#   '',
#   'S/ 1.236,01',
#   'S/ 865,21'),
#  ('Big Data', 'Puneet Goswami', 'S/ 454,68', 'S/ 318,28'),
#  ('Planning 2020: Estrategia, Eficacia, Innovación, big Data y Gestión de Marcas en un Entorno Digital',
#   'Desconocido',
#   'S/ 271,60',
#   'S/ 190,12'),
#  ('Przegląd narzędzi Big Data do analizy rozproszonych danych o kliencie: Porównanie narzędzi Big Data do analizy rozproszonych danych o konsumencie w ... przedsiębiorstwach (Polish Edition)',
#   'Aleksandra Woźniak',
#   'S/ 261,31',
#   'S/ 182,92'),
#  ('Predictive Econometrics and big Data (Studies in Computational Intelligence) (libro en Inglés)',
#   '',
#   'S/ 3.741,51',
#   'S/ 2.619,06'),
#  ('Collecting Experiments: Making big Data Biology (libro en Inglés)',
#   'Bruno J. Strasser',
#   'S/ 425,49',
#   'S/ 297,84'),
#  ('Artificial Intelligence big Data Gathering: Function (libro en inglés)',
#   'Johnny Ch Lok',
#   'S/ 787,80',
#   'S/ 551,46'),
#  ('Big Data',
#   'Enabled Internet Of Things (Computing And Networks) (libro En Inglés)',
#   'S/ 1.002,74',
#   'S/ 701,92'),
#  ('Big Data for Chimps: A Guide to Massive',
#   'Philip Kromer',
#   'S/ 318,96',
#   'S/ 223,28'),
#  ('Artificial Intelligence for big Data (libro en Inglés)',
#   'Anand Deshpande; Manish Kumar',
#   'S/ 439,46',
#   'S/ 307,63'),
#  ('Big Data Recommender Systems: Application Paradigms (Computing and Networks) (libro en Inglés)',
#   '',
#   'S/ 1.031,40',
#   'S/ 721,98'),
#  ('Whither Turbulence and big Data in the 21St Century? (libro en Inglés)',
#   '',
#   'S/ 1.899,23',
#   'S/ 1.329,46'),
#  ('La Protección de Datos de Carácter Sensible: Historia Clinica Digital y big Data en Salud',
#   'Luc&Iacute;A Cristea Uivaru',
#   'S/ 313,77',
#   'S/ 219,64'),
#  ...]

# %%
type(filas)
# Out:
# list

# %%
df_postgresSQL = pd.DataFrame(filas)

# %%
df_postgresSQL.head()
# Out:
#                                                    0               1  \
# 0                                           Big Data  Dawn E. Holmes
# 1                           Big Data Para Directivos      Genis Roca
# 2  Big Data: La Utilización del big Data, el Anál...    Bernard Marr
# 3  Data Strategy: Como Beneficiarse de un Mundo d...    Bernard Marr
# 4                    Big Data, el Poder de los Datos   Bill Schmarzo
#
#            2          3
# 0  S/ 117,98   S/ 82,58
# 1  S/ 113,05   S/ 79,14
# 2  S/ 166,14  S/ 116,30
# 3  S/ 118,42   S/ 82,89
# 4  S/ 186,11  S/ 130,27

# %%
df_postgresSQL.columns=["Nombre_Libro","Autor","Precio_anterior","Precio_Actual"]

# %%
df_postgresSQL.head()
# Out:
#                                         Nombre_Libro           Autor  \
# 0                                           Big Data  Dawn E. Holmes
# 1                           Big Data Para Directivos      Genis Roca
# 2  Big Data: La Utilización del big Data, el Anál...    Bernard Marr
# 3  Data Strategy: Como Beneficiarse de un Mundo d...    Bernard Marr
# 4                    Big Data, el Poder de los Datos   Bill Schmarzo
#
#   Precio_anterior Precio_Actual
# 0       S/ 117,98      S/ 82,58
# 1       S/ 113,05      S/ 79,14
# 2       S/ 166,14     S/ 116,30
# 3       S/ 118,42      S/ 82,89
# 4       S/ 186,11     S/ 130,27

# %% [markdown]
# **CERRAR LA CONEXION**

# %%
conPostg.close()
